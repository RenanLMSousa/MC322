// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
float S = 200;
int N = 5;
float J =1;
for(int i=1;i<=N;i++){
    System.out.println("Parcela " + i + " do financiamento: " + S);
    S*= (1+J/100);
}
// Out:
// @
// Parcela 1 do financiamento: 200.0
// Parcela 2 do financiamento: 202.0
// Parcela 3 do financiamento: 204.02
// Parcela 4 do financiamento: 206.0602
// Parcela 5 do financiamento: 208.12079
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Parcela{
    
    static float calcular_parcelaN(int N, float J, float S){
    //Calcula uma única parcela N
        return (float)Math.pow((1+J/100),N-1)*S;
        
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkr8d0fc96c.Parcela

// %%
float S = 200;
int N = 5;
float J =1;
for(int i=1;i<=N;i++){
    System.out.println("parcela "+ i + " do financiamento: " + Parcela.calcular_parcelaN(i,J,S)); 
}
// Out:
// parcela 1 do financiamento: 200.0
// parcela 2 do financiamento: 202.0
// parcela 3 do financiamento: 204.02
// parcela 4 do financiamento: 206.0602
// parcela 5 do financiamento: 208.1208
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Binario{
    static String decimal_p_binario(int N){
        String resultado ="";
        int dividendo = N;
        int resto;
        
        do{
            resto = dividendo %2;
            dividendo = dividendo/2;
            resultado= resto + resultado;
            
        }
        while(dividendo>=2);
        resultado=resto+resultado;
 return resultado;
    }
   
    
}
// Out:
// com.twosigma.beaker.javash.bkre1ee7e00.Binario

// %%
import java.util.Random;


Random rand = new Random();
int numeroSorteado = rand.nextInt(10000); 


System.out.println(numeroSorteado);
System.out.println(Binario.decimal_p_binario(numeroSorteado));
// Out:
// 1843
// 11100110011
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class MaterialGenetico{
    
    static String DNA_em_RNA(String DNA){
        String RNA="";
        for(int i=0;i<DNA.length();i++){
            switch (DNA.charAt(i)){
                case 'A':
                    RNA+="U";
                    break;
                case 'T':
                    RNA+="A";
                    break;
                case 'C':
                    RNA+="G";
                    break;
                case 'G':
                    RNA+="C";
                    break;
            }
        }
        
        return RNA;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr8d0fc96c.MaterialGenetico

// %%
String DNA = "ATCGATCGATCCG";
System.out.println(MaterialGenetico.DNA_em_RNA(DNA));
// Out:
// UAGCUAGCUAGGC
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

public class Empresa{
    static int[] gerar_salarios(int N){
        
        int[] salario_funcionarios = new int[N];
        Random rand = new Random();
        for(int i=0;i<N;i++){
            salario_funcionarios[i]=(rand.nextInt(12501)+2500);
        }
                
        return salario_funcionarios;
    }
    
    static int salarios_acima_media(int[] salario_funcionarios){
        
        float media=0;
        int n=0;
        int qtd=0;
        for(int salario : salario_funcionarios){
            n++;
            media += (float)salario;
        }
        media/=n;
        
        for(int i =0;i<n;i++){
            if(salario_funcionarios[i]>media){
                qtd++;
            }
            
        }
        return qtd;

    }
    
    static void imprimir_salarios(int[] salario_funcionarios){
        
        for(int salario : salario_funcionarios){
           System.out.println(salario);
        }
    
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkr8d0fc96c.Empresa

// %%
int[] salario_funcionarios=Empresa.gerar_salarios(50);
System.out.println("Salários acima da média: "+Empresa.salarios_acima_media(salario_funcionarios));
System.out.println("Salários :");
Empresa.imprimir_salarios(salario_funcionarios);
// Out:
// Salários acima da média: 23
// Salários :
// 3411
// 11694
// 4708
// 8288
// 11354
// 13138
// 13235
// 7997
// 10320
// 14990
// 7748
// 6367
// 2947
// 7577
// 4303
// 4847
// 2593
// 5444
// 4528
// 11837
// 5503
// 2647
// 14256
// 6997
// 6125
// 8826
// 8769
// 10448
// 2953
// 13081
// 3685
// 10659
// 13885
// 10991
// 12019
// 12960
// 3374
// 5744
// 6366
// 3266
// 7116
// 8619
// 3126
// 5879
// 9224
// 6188
// 6047
// 9014
// 12298
// 14217
// null
